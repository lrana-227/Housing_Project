# %%
import plotly.graph_objects as go

import pandas as pd
df = pd.read_csv('Clean Data/disasters_clean.csv')

# %%
disaster_clean_df = df[["State", "Disaster Type"]]



#disaster_clean_df.drop(["GU","MP","PR","VI","DC","AS"])

state_grp = disaster_clean_df.groupby("State").count()
state_grp
#disaster_clean_df.drop(["MP"],axis = 0)
#disaster_clean_df.drop(["PR"],axis = 0)
#disaster_clean_df.drop(["VI"],axis = 0)
#disaster_clean_df.drop(["DC"],axis = 0)
#disaster_clean_df.drop(["AS"],axis = 0)
# Out:
#        Disaster Type
# State
# AK                26
# AL               141
# AR               193
# AS                 5
# AZ                20
# CA                62
# CO                38
# CT                49
# DC                 6
# DE                 9
# FL               103
# GA               169
# GU                 2
# HI                 9
# IA               302
# ID                21
# IL               159
# IN                72
# KS               210
# KY               387
# LA               168
# MA                61
# MD                98
# ME                24
# MI                19
# MN               213
# MO               345
# MP                 3
# MS               187
# MT               103
# NC               152
# ND               182
# NE               202
# NH                40
# NJ               123
# NM                88
# NV                 1
# NY               143
# OH                62
# OK               309
# OR                41
# PA               136
# ...

# %%
fig = go.Figure(data=go.Choropleth(
    locations=disaster_clean_df['State'], # Spatial coordinates
    z = state_grp['Disaster Type'], # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorbar_title = "Number of Disasters"
))

fig.update_layout(
    title_text = 'US Natural Disasters by State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# <div>                            <div id="ed98acfe-3f4d-438a-9352-540432a23066" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed98acfe-3f4d-438a-9352-540432a23066")) {                    Plotly.newPlot(                        "ed98acfe-3f4d-438a-9352-540432a23066",                        [{"colorbar": {"title": {"text": "Number of Disasters"}}, "locationmode": "USA-states", "locations": ["AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AK", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", "AL", 
# ...
