# %%
import pandas as pd

# %%
#load the file 

disaster_data_to_load = "Clean Data/natural_disasters.csv"

disaster_df = pd.read_csv(disaster_data_to_load)
disaster_df.head()
# Out:
#   Declaration Number Declaration Type Declaration Date State  \
# 0            DR-1992         Disaster          6/10/11    AK
# 1            DR-1992         Disaster          6/10/11    AK
# 2            DR-1992         Disaster          6/10/11    AK
# 3            DR-4050         Disaster         12/22/11    AK
# 4            DR-4050         Disaster         12/22/11    AK
#
#                                               County Disaster Type  \
# 0                            Crooked Creek ANV/ANVSA         Flood
# 1        Kuspuk Regional Educational Attendance Area         Flood
# 2                                Red Devil ANV/ANVSA         Flood
# 3  Bering Strait Regional Educational Attendance ...         Storm
# 4  Lower Kuskokwim Regional Educational Attendanc...         Storm
#
#                       Disaster Title Start Date  End Date  \
# 0               Ice Jam and Flooding     5/8/11   5/13/11
# 1               Ice Jam and Flooding     5/8/11   5/13/11
# 2               Ice Jam and Flooding     5/8/11   5/13/11
# 3  Severe Winter Storms and Flooding    11/8/11  11/13/11
# 4  Severe Winter Storms and Flooding    11/8/11  11/13/11
#
#   Individual Assistance Program Individuals & Households Program  \
# 0                            No                               No
# 1                            No                               No
# 2                            No                               No
# 3                            No                               No
# 4                            No                               No
#
#   Public Assistance Program Hazard Mitigation Program
# 0                       Yes                       Yes
# 1                       Yes                       Yes
# 2                       Yes                       Yes
# 3                       Yes                       Yes
# 4                       Yes                       Yes

# %%
print (len(disaster_df))
# Out:
# 6547

# %%
#how many disasters per year 

disaster_df['year start'] = pd.DatetimeIndex(disaster_df['Start Date']).year
disaster_df['year end'] = pd.DatetimeIndex(disaster_df['End Date']).year
disaster_df.dropna
disaster_df.tail()
# Out:
#      Declaration Number Declaration Type Declaration Date State  \
# 6542            DR-4007         Disaster          7/22/11    WY
# 6543            DR-4227         Disaster           7/7/15    WY
# 6544            DR-4227         Disaster           7/7/15    WY
# 6545            DR-4227         Disaster           7/7/15    WY
# 6546            DR-4227         Disaster           7/7/15    WY
#
#                County Disaster Type                           Disaster Title  \
# 6542    Weston County         Storm  Severe Storms, Flooding, and Landslides
# 6543    Albany County         Flood               Severe Storms and Flooding
# 6544   Johnson County         Flood               Severe Storms and Flooding
# 6545  Niobrara County         Flood               Severe Storms and Flooding
# 6546    Platte County         Flood               Severe Storms and Flooding
#
#      Start Date End Date Individual Assistance Program  \
# 6542    5/18/11   7/8/11                            No
# 6543    5/24/15   6/6/15                            No
# 6544    5/24/15   6/6/15                            No
# 6545    5/24/15   6/6/15                            No
# 6546    5/24/15   6/6/15                            No
#
#      Individuals & Households Program Public Assistance Program  \
# 6542                               No                       Yes
# 6543                              Yes                       Yes
# 6544                              Yes                       Yes
# 6545                              Yes                       Yes
# 6546                              Yes                       Yes
#
#      Hazard Mitigation Program  year start  year end
# 6542                       Yes        2011      2011
# 6543                       Yes        2015      2015
# 6544                       Yes        2015      2015
# 6545                       Yes        2015      2015
# 6546                       Yes        2015      2015

# %%
print (len(disaster_df))
# Out:
# 6547

# %%
disaster_clean_df = disaster_df[[ "State","Disaster Type" , "Disaster Title", "year start", "year end" ]]
disaster_clean_df.head()
# Out:
#   State Disaster Type                     Disaster Title  year start  year end
# 0    AK         Flood               Ice Jam and Flooding        2011      2011
# 1    AK         Flood               Ice Jam and Flooding        2011      2011
# 2    AK         Flood               Ice Jam and Flooding        2011      2011
# 3    AK         Storm  Severe Winter Storms and Flooding        2011      2011
# 4    AK         Storm  Severe Winter Storms and Flooding        2011      2011

# %%
disaster_clean_df.to_csv("Clean Data/disasters_clean.csv")
